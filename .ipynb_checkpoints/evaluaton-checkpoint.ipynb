# %% [markdown]
# # China v. USA: A Comparison
#
# For this notebook I will be exploring various different data points collected on China and the USA by reputable sources and comparing the growth of each country.
#
# The data used in this notebook is sourced form the [World Bank World Development Index](https://datacatalog.worldbank.org/dataset/world-development-indicators) data set.

# %% [markdown]
# ## Initialisation

# %%
import pandas as pd
from matplotlib import colors
import matplotlib.pyplot as plt
from matplotlib.ticker import EngFormatter
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns

# %% [markdown]
# Now we load and visually inspect the data.

# %%
data = pd.read_csv('data/raw/WDI_csv/WDIData.csv')

print(data.head())
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...            2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN     ...       82.783289  83.120303  83.533457
# 1   NaN   NaN   NaN   NaN   NaN     ...       86.428272  87.070576  88.176836
# 2   NaN   NaN   NaN   NaN   NaN     ...       73.942103  75.244104  77.162305
# 3   NaN   NaN   NaN   NaN   NaN     ...       95.939242  95.962166  96.352930
# 4   NaN   NaN   NaN   NaN   NaN     ...       22.260538        NaN        NaN
#
#         2014       2015       2016       2017  2018  2019  Unnamed: 64
# 0  83.897596  84.171599  84.510171        NaN   NaN   NaN          NaN
# 1  87.342739  89.130121  89.678685  90.273687   NaN   NaN          NaN
# 2  75.538976  78.741152  79.665635  80.749293   NaN   NaN          NaN
# 3  95.997833  96.649916  96.834184  97.003974   NaN   NaN          NaN
# 4  30.277130        NaN        NaN  37.165211   NaN   NaN          NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# The first thing I notice here is the structure of the data. Each row appears to be a data point for a given indicator and country. The columns consist of relevant information such as the idicator code followe by one column for each year. This is not the format that pandas supports so we must restruture the data first before we can analse and plot it.
#
# Also, the value of the `Country Name` field in the first rows is `Arab World`. Clearly this is not a country name and suggests the data is using some other classification groups.

# %%
print(data['Country Name'].unique())
# Out:
# ['Arab World' 'Caribbean small states' 'Central Europe and the Baltics'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD countries)' 'Euro area'
#  'Europe & Central Asia' 'Europe & Central Asia (excluding high income)'
#  'Europe & Central Asia (IDA & IBRD countries)' 'European Union'
#  'Fragile and conflict affected situations'
#  'Heavily indebted poor countries (HIPC)' 'High income' 'IBRD only'
#  'IDA & IBRD total' 'IDA blend' 'IDA only' 'IDA total'
#  'Late-demographic dividend' 'Latin America & Caribbean'
#  'Latin America & Caribbean (excluding high income)'
#  'Latin America & the Caribbean (IDA & IBRD countries)'
#  'Least developed countries: UN classification' 'Low & middle income'
#  'Low income' 'Lower middle income' 'Middle East & North Africa'
#  'Middle East & North Africa (excluding high income)'
#  'Middle East & North Africa (IDA & IBRD countries)' 'Middle income'
#  'North America' 'Not classified' 'OECD members' 'Other small states'
#  'Pacific island small states' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'Small states' 'South Asia'
#  'South Asia (IDA & IBRD)' 'Sub-Saharan Africa'
#  'Sub-Saharan Africa (excluding high income)'
#  'Sub-Saharan Africa (IDA & IBRD countries)' 'Upper middle income' 'World'
#  'Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czech Republic'
#  'Denmark' 'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador'
#  'Egypt, Arab Rep.' 'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia'
#  'Eswatini' 'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France'
#  'French Polynesia' 'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana'
#  'Gibraltar' 'Greece' 'Greenland' 'Grenada' 'Guam' 'Guatemala' 'Guinea'
#  'Guinea-Bissau' 'Guyana' 'Haiti' 'Honduras' 'Hong Kong SAR, China'
#  'Hungary' 'Iceland' 'India' 'Indonesia' 'Iran, Islamic Rep.' 'Iraq'
#  'Ireland' 'Isle of Man' 'Israel' 'Italy' 'Jamaica' 'Japan' 'Jordan'
#  'Kazakhstan' 'Kenya' 'Kiribati' 'Korea, Dem. People’s Rep.' 'Korea, Rep.'
#  'Kosovo' 'Kuwait' 'Kyrgyz Republic' 'Lao PDR' 'Latvia' 'Lebanon'
#  'Lesotho' 'Liberia' 'Libya' 'Liechtenstein' 'Lithuania' 'Luxembourg'
#  'Macao SAR, China' 'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Mali'
#  'Malta' 'Marshall Islands' 'Mauritania' 'Mauritius' 'Mexico'
#  'Micronesia, Fed. Sts.' 'Moldova' 'Monaco' 'Mongolia' 'Montenegro'
#  'Morocco' 'Mozambique' 'Myanmar' 'Namibia' 'Nauru' 'Nepal' 'Netherlands'
#  'New Caledonia' 'New Zealand' 'Nicaragua' 'Niger' 'Nigeria'
#  'North Macedonia' 'Northern Mariana Islands' 'Norway' 'Oman' 'Pakistan'
#  'Palau' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru' 'Philippines'
#  'Poland' 'Portugal' 'Puerto Rico' 'Qatar' 'Romania' 'Russian Federation'
#  'Rwanda' 'Samoa' 'San Marino' 'Sao Tome and Principe' 'Saudi Arabia'
#  'Senegal' 'Serbia' 'Seychelles' 'Sierra Leone' 'Singapore'
#  'Sint Maarten (Dutch part)' 'Slovak Republic' 'Slovenia'
#  'Solomon Islands' 'Somalia' 'South Africa' 'South Sudan' 'Spain'
#  'Sri Lanka' 'St. Kitts and Nevis' 'St. Lucia' 'St. Martin (French part)'
#  'St. Vincent and the Grenadines' 'Sudan' 'Suriname' 'Sweden'
#  'Switzerland' 'Syrian Arab Republic' 'Tajikistan' 'Tanzania' 'Thailand'
#  'Timor-Leste' 'Togo' 'Tonga' 'Trinidad and Tobago' 'Tunisia' 'Turkey'
#  'Turkmenistan' 'Turks and Caicos Islands' 'Tuvalu' 'Uganda' 'Ukraine'
#  'United Arab Emirates' 'United Kingdom' 'United States' 'Uruguay'
#  'Uzbekistan' 'Vanuatu' 'Venezuela, RB' 'Vietnam' 'Virgin Islands (U.S.)'
#  'West Bank and Gaza' 'Yemen, Rep.' 'Zambia' 'Zimbabwe']

# %%
all_countries = data['Country Name'].unique()[47:]
countries_data = data.loc[data['Country Name'].isin(all_countries)]

print(countries_data.head())
# Out:
#       Country Name Country Code  \
# 67163  Afghanistan          AFG
# 67164  Afghanistan          AFG
# 67165  Afghanistan          AFG
# 67166  Afghanistan          AFG
# 67167  Afghanistan          AFG
#
#                                           Indicator Name     Indicator Code  \
# 67163  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 67164            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 67165  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 67166  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 67167  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
#
#        1960  1961  1962  1963  1964  1965     ...            2011       2012  \
# 67163   NaN   NaN   NaN   NaN   NaN   NaN     ...       22.330000  24.080000
# 67164   NaN   NaN   NaN   NaN   NaN   NaN     ...       43.222019  69.100000
# 67165   NaN   NaN   NaN   NaN   NaN   NaN     ...       29.572881  60.849156
# 67166   NaN   NaN   NaN   NaN   NaN   NaN     ...       86.567779  95.000000
# 67167   NaN   NaN   NaN   NaN   NaN   NaN     ...        9.005013        NaN
#
#             2013       2014       2015      2016       2017  2018  2019  \
# 67163  26.170000  27.990000  30.100000  32.44000        NaN   NaN   NaN
# 67164  70.153481  89.500000  71.500000  97.70000  97.700000   NaN   NaN
# 67165  62.875693  86.500512  64.573354  97.09936  97.091973   NaN   NaN
# 67166  92.735733  98.700000  92.500000  99.50000  99.500000   NaN   NaN
# 67167        NaN   9.961000        NaN       NaN  14.893312   NaN   NaN
#
#        Unnamed: 64
# 67163          NaN
# 67164          NaN
# 67165          NaN
# 67166          NaN
# 67167          NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Setup

# %%
# ensure consistent coloring of countries in the notebook
COLOR_DICT = {
    'China': '#ff0000',
    'United States': '#0000ff',
    'United Kingdom': '#00df00',
    'Germany': '#ffaa00',
    'France': '#ff33cc',
    'Italy': '#009933',
    'Japan': '#00ffff'
}

DEFAULT_COUNTRIES = ["CHN", "USA"]
DEFAULT_YEARS = list(map(lambda x: str(x), range(1960, 2019 + 1)))

# reshape data to have years as rows and countries as columns within a specified range
def get_reshaped_dataframe(ind_code, countries, years):
    dataframes = {}
    
    # get rows for each country
    for country in countries:
        row = countries_data.loc[(countries_data['Country Code'] == country) & (countries_data['Indicator Code'] == ind_code)]
        dataframes[row['Country Name'].iloc[0]] = row
    
    # concat each row into single data frame
    joined_df = pd.concat(dataframes, ignore_index=True).set_index('Country Name')
    joined_df.index.name = None
    
    indicator_name = joined_df['Indicator Name'].iloc[0]

    # only plot data that is present
    available_years = [year for year in years if year in joined_df.columns]
    joined_df = joined_df[available_years].transpose()

    joined_df = joined_df.set_index(pd.to_datetime(joined_df.index))
    
    return (indicator_name, joined_df)

def get_indicator_change(ind_code, countries, years, use_percentage):
    (indicator_name, df) = get_reshaped_dataframe(ind_code, countries, years)
    
    if use_percentage:
        df = df.pct_change(axis=0).drop(df.index[0]).applymap(lambda x: x * 100)
    else:
        df = df.diff(axis=0).drop(df.index[0])
    
    return (indicator_name, df)

# plot the specified indicator on a line graph
def plot_indicator_line(ind_code, countries=None, years=None):
    if countries is None:
        countries = DEFAULT_COUNTRIES
    
    if years is None:
        years = DEFAULT_YEARS

    (indicator_name, df) = get_reshaped_dataframe(ind_code, countries, years)
    
    df.plot.line(figsize=(10,5), color=[COLOR_DICT.get(x, '#333333') for x in df.columns])
    
    ax = plt.gca()
    ax.set(xlabel='Year', ylabel=indicator_name)
    ax.grid(color='grey', linestyle='--', linewidth=0.5, axis='y')

    formatter = EngFormatter()
    ax.yaxis.set_major_formatter(formatter)
    
    plt.margins(x=0.02)
    plt.show()

# plot the % change of an indicator on a graph
def plot_indicator_change(ind_code, countries=None, years=None, use_percentage=True):
    if countries is None:
        countries = DEFAULT_COUNTRIES
    
    if years is None:
        years = DEFAULT_YEARS

    (indicator_name, df) = get_indicator_change(ind_code, countries, years, use_percentage)
    
    ax = df.plot.line(figsize=(10,5), color=[COLOR_DICT.get(x, '#333333') for x in df.columns])
    
    ax.set(xlabel='Year', ylabel=indicator_name)
    ax.grid(color='grey', linestyle='--', linewidth=0.5, axis='y')
    
    formatter = EngFormatter()
    ax.yaxis.set_major_formatter(formatter)
    
    plt.margins(x=0.02)

# plot a boxplot of the change in values for a given indicator (defaults to using percentage change)
def boxplot_indicator_change(ind_code, countries=None, years=None, use_percentage=True):
    if countries is None:
        countries = DEFAULT_COUNTRIES
    
    if years is None:
        years = DEFAULT_YEARS

    (indicator_name, df) = get_indicator_change(ind_code, countries, years, use_percentage)
    
    if use_percentage:
        y_label = indicator_name + " (year-over-year change in %)"
    else:
        y_label = indicator_name + " (year-over-year change)"
    
    title = "For the period " + years[1] + "-" + years[-1]

    ax = df.boxplot(figsize=(10,5))
    ax.set(xlabel='Country', ylabel=y_label, title=title)
    
    formatter = EngFormatter()
    ax.yaxis.set_major_formatter(formatter)

# return the % change of an indicator in table format
def table_indicator_change(ind_code, countries=None, years=None, use_percentage=True):
    if countries is None:
        countries = DEFAULT_COUNTRIES
    
    if years is None:
        years = DEFAULT_YEARS

    (indicator_name, df) = get_indicator_change(ind_code, countries, years, use_percentage)
   
    df.index = df.index.strftime('%Y')

    if use_percentage:
        print(indicator_name + " (year-over-year change in %)")
    else:
        print(indicator_name + " (year-over-year change)")

    # ensure that colour range is centred around 0 so red is -ve and green is +ve
    min_val = df.dropna().min().min()
    max_val = df.dropna().max().max()
    abs_max = max(abs(min_val), abs(max_val))

    cmap = LinearSegmentedColormap.from_list(name='red_to_green', colors=['red','white','green'])
    s = df.style.apply(background_gradient, cmap=cmap, m=-abs_max, M=abs_max)

    return s

# apply given background color map to table
def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low), M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]

# plot 2 indicators simultaneously with 2 y-axes
def plot_indicator_comparison(ind_code_1, ind_code_2, country=None, years=None):    
    if years is None:
        years = DEFAULT_YEARS

    (ind_name_1, df_1) = get_reshaped_dataframe(ind_code_1, countries=[country], years=years)
    (ind_name_2, df_2) = get_reshaped_dataframe(ind_code_2, countries=[country], years=years)
    
    country_name = df_1.columns[0]
    
    # label line as indicator name
    df_1 = df_1.rename(columns={df_1.columns[0]: ind_name_1})
    df_2 = df_2.rename(columns={df_2.columns[0]: ind_name_2})
    
    ax1 = df_1.plot.line(figsize=(10,5), color='orange')
    ax2 = df_2.plot.line(figsize=(10,5), color='green', secondary_y=True, ax=ax1)
    
    ax1.grid(color='sandybrown', linestyle='--', linewidth=0.5, axis='y')
    ax2.grid(color='palegreen', linestyle='--', linewidth=0.5, axis='y')

    ax1.set_xlabel('Year')
    ax1.set_title(country_name)
    ax1.set_ylabel(ind_name_1)
    ax2.set_ylabel(ind_name_2)
    
    formatter = EngFormatter()
    ax1.yaxis.set_major_formatter(formatter)
    ax2.yaxis.set_major_formatter(formatter)

# return the top n values for a given indicator and year
def indicator_top_values(ind_code, n=5, year="2018"):
    df = countries_data.loc[countries_data['Indicator Code'] == ind_code]
    
    top_n = df.sort_values(by=year, ascending=False).head(n)
    
    # set index as rank from 1 to n
    top_n.index = top_n[year].rank(method='first', ascending=False).astype(int)
    top_n.index.name = None
    
    top_n[year] = top_n.apply(lambda x: "{:,.0f}".format(x[year]), axis=1)
    
    print(top_n['Indicator Name'].iloc[0])
    
    return top_n[['Country Name', year]]

# %% [markdown]
# ## Economy

# %%
plot_indicator_line("NY.GDP.MKTP.CD")

# %% [markdown]
# Above we see the GDP for the US is greater than China's and has been since data was first recorded.
#
# We also see that just before 2010 the US saw a contraction in its GDP per capita. This is likely due to the sub-prime mortgage crisis which occured in 2008 and plunged many of the worlds nations into recession. Interestingly, we notice that China saw very little disruption to its GDP during this period.
#
# To investigate this further, we plot the GDP per capita (to ensure similar scales) for both China and the US along with various other developed coutries. The G7 is a group of 7 of the largest advanced economies in the world which represents 58% of the global net wealth (note: the G7 includes the US). Plotting each G7 country with the US and China we see all countries aside from China saw some sort of ecomonic contraction around the period of 2008-2009 when the crisis was at its peak.
#
# This suggests China is somewhat economically independent of the US and the rest of the world.

# %%
g7_and_china = ["CHN", "USA", "GBR", "DEU", "CAN", "FRA", "JPN", "ITA"]

plot_indicator_line("NY.GDP.PCAP.CD", countries=g7_and_china)

# %% [markdown]
# To determine the extent of the economic slow-downs we look at the percentage change in GDP for each of the above countries. The period we choose is from 1995 to the current day. This was chosen because it includes various economic downturns including the 2008 sub-prime mortgage crisis, the 2000 dot-com bubble, the 1997 Asian economic downturn leading to a global 'mini crash', along with the recovery periods for each.

# %%
# 1995-2018
gdp_diff_years = list(map(lambda x: str(x), range(1994, 2018 + 1)))

table_indicator_change("NY.GDP.MKTP.CD", countries=g7_and_china, years=gdp_diff_years)
# Out:
# GDP (current US$) (year-over-year change in %)
# <style  type="text/css" >
#     #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col0 {
#             background-color:  #d8ecd8;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col1 {
#             background-color:  #008000;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col2 {
#             background-color:  #80c080;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col3 {
#             background-color:  #6cb66c;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col4 {
#             background-color:  #c4e2c4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col5 {
#             background-color:  #a2d1a2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col6 {
#             background-color:  #6ab56a;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row0_col7 {
#             background-color:  #d6ebd6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col0 {
#             background-color:  #dceedc;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col1 {
#             background-color:  #6ab56a;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col2 {
#             background-color:  #fcfefc;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col3 {
#             background-color:  #ffe2e2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col4 {
#             background-color:  #9cce9c;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col5 {
#             background-color:  #ffa0a0;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col6 {
#             background-color:  #d0e8d0;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row1_col7 {
#             background-color:  #cee7ce;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col0 {
#             background-color:  #deefde;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col1 {
#             background-color:  #9ecf9e;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col2 {
#             background-color:  #ffaeae;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col3 {
#             background-color:  #ff9e9e;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col4 {
#             background-color:  #ffd2d2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col5 {
#             background-color:  #ffb6b6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col6 {
#             background-color:  #a8d4a8;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row2_col7 {
#             background-color:  #cae5ca;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col0 {
#             background-color:  #ffe4e4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col1 {
#             background-color:  #c4e2c4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col2 {
#             background-color:  #e2f1e2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col3 {
#             background-color:  #f4faf4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col4 {
#             background-color:  #ecf6ec;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col5 {
#             background-color:  #ffb6b6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col6 {
#             background-color:  #cee7ce;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row3_col7 {
#             background-color:  #cee7ce;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col0 {
#             background-color:  #c4e2c4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col1 {
#             background-color:  #cae5ca;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col2 {
#             background-color:  #fffafa;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col3 {
#             background-color:  #ffeeee;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col4 {
#             background-color:  #fff2f2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col5 {
#             background-color:  #90c890;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col6 {
#             background-color:  #eef7ee;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row4_col7 {
#             background-color:  #cae5ca;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col0 {
#             background-color:  #acd6ac;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col1 {
#             background-color:  #a4d2a4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col2 {
#             background-color:  #ffb4b4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col3 {
#             background-color:  #ff9e9e;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col4 {
#             background-color:  #ffb6b6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col5 {
#             background-color:  #c2e1c2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col6 {
#             background-color:  #fff2f2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row5_col7 {
#             background-color:  #c8e4c8;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col0 {
#             background-color:  #fff8f8;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col1 {
#             background-color:  #a6d3a6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col2 {
#             background-color:  #f6fbf6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col3 {
#             background-color:  #fefffe;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col4 {
#             background-color:  #eef7ee;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col5 {
#             background-color:  #ff9a9a;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col6 {
#             background-color:  #fff6f6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row6_col7 {
#             background-color:  #e4f2e4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col0 {
#             background-color:  #e6f3e6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col1 {
#             background-color:  #acd6ac;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col2 {
#             background-color:  #b6dbb6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col3 {
#             background-color:  #c8e4c8;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col4 {
#             background-color:  #b4dab4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col5 {
#             background-color:  #ffdada;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col6 {
#             background-color:  #b4dab4;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row7_col7 {
#             background-color:  #e2f1e2;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col0 {
#             background-color:  #68b468;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col1 {
#             background-color:  #92c992;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col2 {
#             background-color:  #3a9d3a;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col3 {
#             background-color:  #50a850;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col4 {
#             background-color:  #349a34;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col5 {
#             background-color:  #baddba;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col6 {
#             background-color:  #80c080;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row8_col7 {
#             background-color:  #d6ebd6;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row9_col0 {
#             background-color:  #82c182;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row9_col1 {
#             background-color:  #68b468;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row9_col2 {
#             background-color:  #80c080;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row9_col3 {
#             background-color:  #94ca94;
#         }    #T_0d5b96ca_8c95_11ea_a2fb_f45c8999ead5row9_col4 {
#             bac

# %% [markdown]
# The most obvious observation from this table is the relentless growth of China's economy. From 1995 to the current time there has been a constant economic expansion with 3 separate years seeing around 30% growth in GDP. The US also saw a period of almost continuos expansion during this period but to a lesser lagnitude than China.

# %%
boxplot_indicator_change("NY.GDP.MKTP.CD", years=gdp_diff_years)

# %% [markdown]
# Plotting year-over-year (percentage) change of GDP for both China and the US illustrates the stark difference of the nations GDP growth statistics.
#
# The comparatively smaller range of the United States' year-over-year growth make sense given the context. The US -- a well-established superpower -- sees a generally slower but more consistent growth of GDP. This plot paints a picture of sustained rapid growth of China's GDP.

# %%
plot_indicator_line("NE.EXP.GNFS.ZS")
plot_indicator_line("NE.EXP.GNFS.CD")
plot_indicator_comparison("NY.GDP.MKTP.CD", "NE.EXP.GNFS.CD", country="CHN")
plot_indicator_comparison("NY.GDP.MKTP.CD", "NE.EXP.GNFS.CD", country="USA")

# %% [markdown]
# ## Military expenditure

# %%
indicator_top_values("MS.MIL.XPND.CD", n=10)
# Out:
# Military expenditure (current USD)
#           Country Name             2018
# 1        United States  648,798,273,000
# 2                China  249,996,900,635
# 3         Saudi Arabia   67,554,666,667
# 4                India   66,510,289,108
# 5               France   63,799,676,593
# 6   Russian Federation   61,387,546,980
# 7       United Kingdom   49,997,192,521
# 8              Germany   49,470,627,811
# 9                Japan   46,617,954,864
# 10         Korea, Rep.   43,069,973,343

# %% [markdown]
# The US and China rank as the countries with the highest and second-highest military spending respectively with the US military budget being more than double that of China's.
#
# The budget of the american and chinese military overshadows all other nations with the chinese budget being more than 3 times larger than the next largest neighbour, Saudi Arabia. The US budget is nearly 10 times larger than Saudi Arabia's.

# %%
plot_indicator_line("MS.MIL.XPND.CD")

# %% [markdown]
# We choose a period of 1989-2018 to compare data points for the US and China. Before that time China has not published any official figures on its total military expenditure.
#
# Military expenditure for the period of 1989-2018 was considerably higher for the US with two significant peaks. The first peak, starting around 1970, can likely be attributed to the Cold War and the escalating tensions between the US and Soviet Union. In 1991 the Soviet Union was dissolved reducing the hostility between the nations and resulting in a contraction of the military budget. The second peak can be attributed to the US "War on Terror" -- which included the invasion of Iraq and Afghanistan -- following the 9/11 attacks in 2001. This war would become the longest and 2nd most expensive war in US history.
#
# In comparison China has seen a relatively steady and consistent growth in military spending.

# %%
# the only years with data available for China
mil_exp_years = list(map(lambda x: str(x), range(1989, 2018 + 1)))

table_indicator_change("MS.MIL.XPND.CD", years=mil_exp_years)
# Out:
# Military expenditure (current USD) (year-over-year change in %)
# <style  type="text/css" >
#     #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row0_col0 {
#             background-color:  #ff9292;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row0_col1 {
#             background-color:  #f8fcf8;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row1_col0 {
#             background-color:  #fff2f2;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row1_col1 {
#             background-color:  #ffaeae;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row2_col0 {
#             background-color:  #148a14;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row2_col1 {
#             background-color:  #aad5aa;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row3_col0 {
#             background-color:  #f4faf4;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row3_col1 {
#             background-color:  #ffe8e8;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row4_col0 {
#             background-color:  #ff4040;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row4_col1 {
#             background-color:  #ffe0e0;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row5_col0 {
#             background-color:  #0e870e;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row5_col1 {
#             background-color:  #ffe0e0;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row6_col0 {
#             background-color:  #6cb66c;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row6_col1 {
#             background-color:  #ffe6e6;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row7_col0 {
#             background-color:  #9acd9a;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row7_col1 {
#             background-color:  #eef7ee;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row8_col0 {
#             background-color:  #acd6ac;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row8_col1 {
#             background-color:  #fff8f8;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row9_col0 {
#             background-color:  #42a142;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row9_col1 {
#             background-color:  #e8f4e8;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row10_col0 {
#             background-color:  #aad5aa;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row10_col1 {
#             background-color:  #baddba;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row11_col0 {
#             background-color:  #329932;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row11_col1 {
#             background-color:  #dceedc;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row12_col0 {
#             background-color:  #6eb76e;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row12_col1 {
#             background-color:  #7abd7a;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row13_col0 {
#             background-color:  #a6d3a6;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row13_col1 {
#             background-color:  #64b264;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row14_col0 {
#             background-color:  #72b972;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row14_col1 {
#             background-color:  #8ec78e;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row15_col0 {
#             background-color:  #7cbe7c;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row15_col1 {
#             background-color:  #b0d8b0;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row16_col0 {
#             background-color:  #3c9e3c;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row16_col1 {
#             background-color:  #d2e9d2;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row17_col0 {
#             background-color:  #269326;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row17_col1 {
#             background-color:  #cae5ca;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row18_col0 {
#             background-color:  #008000;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row18_col1 {
#             background-color:  #92c992;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row19_col0 {
#             background-color:  #2c962c;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row19_col1 {
#             background-color:  #b6dbb6;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row20_col0 {
#             background-color:  #a4d2a4;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row20_col1 {
#             background-color:  #d4ead4;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row21_col0 {
#             background-color:  #48a448;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row21_col1 {
#             background-color:  #eef7ee;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row22_col0 {
#             background-color:  #7abd7a;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row22_col1 {
#             background-color:  #ffdcdc;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row23_col0 {
#             background-color:  #78bc78;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row23_col1 {
#             background-color:  #ffc0c0;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row24_col0 {
#             background-color:  #90c890;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row24_col1 {
#             background-color:  #ffd2d2;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row25_col0 {
#             background-color:  #c0e0c0;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row25_col1 {
#             background-color:  #ffeaea;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row26_col0 {
#             background-color:  #f6fbf6;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row26_col1 {
#             background-color:  #f8fcf8;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row27_col0 {
#             background-color:  #cce6cc;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row27_col1 {
#             background-color:  #f6fbf6;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row28_col0 {
#             background-color:  #a2d1a2;
#         }    #T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row28_col1 {
#             background-color:  #bcdebc;
#         }</style>
# <table id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >China</th>
#         <th class="col_heading level0 col1" >United States</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5level0_row0" class="row_heading level0 row0" >1990</th>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row0_col0" class="data row0 col0" >-11.5612</td>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row0_col1" class="data row0 col1" >0.685664</td>
#     </tr>    <tr>
#         <th id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5level0_row1" class="row_heading level0 row1" >1991</th>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row1_col0" class="data row1 col0" >-1.30331</td>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row1_col1" class="data row1 col1" >-8.45217</td>
#     </tr>    <tr>
#         <th id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5level0_row2" class="row_heading level0 row2" >1992</th>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row2_col0" class="data row2 col0" >24.7815</td>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row2_col1" class="data row2 col1" >8.8654</td>
#     </tr>    <tr>
#         <th id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5level0_row3" class="row_heading level0 row3" >1993</th>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row3_col0" class="data row3 col0" >1.26297</td>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row3_col1" class="data row3 col1" >-2.45919</td>
#     </tr>    <tr>
#         <th id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5level0_row4" class="row_heading level0 row4" >1994</th>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row4_col0" class="data row4 col0" >-20.0886</td>
#         <td id="T_0f99fbd4_8c95_11ea_a2fb_f45c8999ead5row4_c

# %%
plot_indicator_comparison("NY.GDP.MKTP.CD", "MS.MIL.XPND.CD", country="USA")
plot_indicator_comparison("NY.GDP.MKTP.CD", "MS.MIL.XPND.CD", country="CHN")

# %% [markdown]
# A further interesting comparison we can make is between GDP and military expenditure. The US saw two significant surges in military spending, as mentioned earlier, due to the Cold War and the War on Terror. The act of war (or the threat of its impending arrival) is expensive and requires large increases in spending that may not necessarily correlate with the economic growth of the country.
#
# Looking at China was can see military expenditure is very closely correlated with GDP. China has experienced conflicts in this time but not on the scale of the US wars. This suggests that China is experiencing more of a 'natural' growth of its military, powered by its growing economic and political influence internationally. Having said that, this does not exclude the possibility of war as a motivator for China. The US and China are very different both in terms of ideology and their strategic goals around the world.

# %% [markdown]
# ## Health

# %%
plot_indicator_line("SH.XPD.CHEX.PC.CD")

# %%
plot_indicator_line("SP.DYN.LE00.IN")

# %% [markdown]
# Perhaps one of the most encouraging and pronounced signs of progress in China is the life expectancy of its citizens.

# %% [markdown]
# ## Environment

# %%
plot_indicator_line("EN.ATM.CO2E.PC")

# %%
plot_indicator_line("EN.ATM.GHGT.KT.CE")

# %%
plot_indicator_line("EG.ELC.RNWX.ZS")

# %% [markdown]
# ## Transport

# %%
plot_indicator_line("IS.AIR.PSGR")

# %% [markdown]
# ## Conclusion
#
# - general picture that China is currently behind but rapidly closing the gap
